# %% [markdown]
# <a href="https://colab.research.google.com/github/Mazen7676/colab-vocal-splitter-thingy/blob/main/UVR_v5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 1. SETUP UVR5 BETA - v5.0.2

#@markdown * Grant access to Google Drive
#@markdown * Install dependencies

import datetime
import time
from IPython.display import clear_output
import IPython
import uuid
from google.colab import output
from os import path
from pathlib import Path
from IPython.display import Audio, display
from google.colab import output
from google.colab import drive
from google.colab import files
from sys import exit
import zipfile
import hashlib
import os.path
import shutil
import psutil
import random
import glob
import sys
import os
import os.path
os.system('clear')

# !pip install soundstretch
# !pip install samplerate
clear_output()

drive_path = '/content/drive/My Drive' # DEFAULT
ai = 'https://github.com/lucassantilli/UVR-Colab-GUI'

## DOWNLOADABLE MODELS
model_1 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/HP2-4BAND-3090_4band_1.pth'
model_2 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/HP2-4BAND-3090_4band_2.pth'
model_3 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/HP_4BAND_3090.pth'
model_4 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/HighPrecison_4band_1.pth'
model_5 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/HighPrecison_4band_2.pth'
model_6 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/NewLayer_4band_1.pth'
model_7 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/NewLayer_4band_2.pth'
model_8 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/NewLayer_4band_3.pth'
model_9 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-2Band-32000-BETA1.pth'
model_10 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-2Band-32000-BETA2.pth'
model_11 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-3Band-44100-BETA.pth'
model_12 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-4Band-44100-BETA1.pth'
model_13 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-4Band-44100-BETA2.pth'
model_14 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-MIDSIDE-44100-BETA1.pth'
model_15 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-MIDSIDE-44100-BETA2.pth'
model_16 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/Vocal_HP_4BAND_3090.pth'
model_17 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/Vocal_HP_4BAND_3090_AGG.pth'
model_18 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-Vocal_2Band-32000-BETA1.pth'
model_19 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-Vocal_2Band-32000-BETA2.pth'
model_20 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-KAROKEE-32000-BETA1.pth'
model_21 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/MGM-v5-KAROKEE-32000-BETA2-AGR.pth'
model_22 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/LOFI_2band-1_33966KB.pth'
model_23 = 'https://github.com/lucassantilli/UVR-Colab-GUI/releases/download/m5.1/LOFI_2band-2_33966KB.pth'

class hide_opt: # hide outputs
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')
    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

def get_size(bytes, suffix='B'): # read ram
    global svmem
    factor = 1024
    for unit in ["", "K", "M", "G", "T", "P"]:
        if bytes < factor:
            return f'{bytes:.2f}{unit}{suffix}'
        bytes /= factor
    svmem = psutil.virtual_memory()

def installAI():
    with hide_opt():

        get_ipython().system('git clone {} UVR_v5'.format(ai))
        os.chdir('UVR_v5')

def mount_to_colab(): # uvr found
    os.chdir(f'{drive_path}/UVR_v5/models')
    clear_output()
    print(f'UVR5 is installed in {drive_path}/UVR_v5')
    print("Finished on " + datetime.datetime.now().strftime("%d/%m/%Y at %H:%M:%S"))

def vrmount(): # install uvr to gdrive
    print("Mounting Google Drive...")
    drive.mount("/content/drive")
    os.chdir(drive_path + '/')
    if os.path.isdir(f'{drive_path}/UVR_v5'):
        mount_to_colab()
    else:
        print("UVR5 not found. Downloading from GitHub...")
        installAI()
        mount_to_colab()

vrmount()
# Out:
# UVR5 is installed in /content/drive/My Drive/UVR_v5
# Finished on 07/08/2026 at 22:29:32

# %%
# !pip install "numpy<2.0.0" "librosa==0.9.2" "soundfile==0.12.1"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 84.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: soundfile
#     Found existing installation: soundfile 0.14.0
#     Uninstalling soundfile-0.14.0:
#       Successfully uninstalled soundfile-0.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
import os, glob, subprocess
from pydub import AudioSegment

# Configuration
INPUT_DIR = "/content/drive/MyDrive/songs"       # Path to your source folder
FILENAME = "2026-08-03 20-44-420001.wav"        # Exact filename
CHUNK_MINUTES = 5                               # Sliced into 5-minute chunks
TEMP_DIR = "/content/audio_chunks"
OUTPUT_DIR = "/content/drive/MyDrive/UVR_v5/separated/converted"

os.makedirs(TEMP_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

file_path = os.path.join(INPUT_DIR, FILENAME)
print(f"Loading full audio file: {file_path}")
audio = AudioSegment.from_file(file_path)

# 1. Split into chunks
chunk_length_ms = CHUNK_MINUTES * 60 * 1000
chunks = [audio[i:i + chunk_length_ms] for i in range(0, len(audio), chunk_length_ms)]
print(f"Split file into {len(chunks)} chunks of {CHUNK_MINUTES} minutes each.")

chunk_files = []
for i, chunk in enumerate(chunks):
    chunk_filename = os.path.join(TEMP_DIR, f"chunk_{i:03d}.wav")
    chunk.export(chunk_filename, format="wav")
    chunk_files.append(chunk_filename)

print("Chunking complete! Running UVR on individual chunks...")
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Loading full audio file: /content/drive/MyDrive/songs/2026-08-03 20-44-420001.wav
# Split file into 29 chunks of 5 minutes each.
# Chunking complete! Running UVR on individual chunks...

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Model:", torch.cuda.get_device_name(0))
else:
    print("WARNING: Running on CPU!")

# %%
#@title 2. INFERENCE
#@markdown ###Input Options
from pathlib import Path
my_suffixes = (".wav", ".mp3", ".m4a", ".weba", ".flac", ".ogg")

run_true = "yes"
temp_folder= './separated/temp'
Input = "Please Mind That This Is CASE SENSITIVE.flac" #@param {type:"string"}
Folder = '/content/audio_chunks' #@param ["/content/drive/My Drive/songs/", "/content/drive/My Drive/tracks/"] {allow-input: true}
input_folder= './separated'
output_folder= './separated/converted'

All_Files = True #@param {type:"boolean"}

#@markdown

#@markdown ###Inference Options
Model = "VOCAL Vocal_HP_4BAND_3090_AGG" #@param ["HP2-4BAND-3090_4band_1", "HP2-4BAND-3090_4band_2", "HP_4BAND_3090", "HighPrecison_4band_1", "HighPrecison_4band_2", "NewLayer_4band_1", "NewLayer_4band_2", "NewLayer_4band_3", "MGM-v5-2Band-32000-BETA1", "MGM-v5-2Band-32000-BETA2", "MGM-v5-3Band-44100-BETA", "MGM-v5-4Band-44100-BETA1", "MGM-v5-4Band-44100-BETA2", "MGM-v5-MIDSIDE-44100-BETA1", "MGM-v5-MIDSIDE-44100-BETA2", "VOCAL Vocal_HP_4BAND_3090", "VOCAL Vocal_HP_4BAND_3090_AGG", "VOCAL MGM-v5-Vocal_2Band-32000-BETA1", "VOCAL MGM-v5-Vocal_2Band-32000-BETA2", "KARAOKE MGM-v5-KAROKEE-32000-BETA1", "KARAOKE MGM-v5-KAROKEE-32000-BETA2-AGR", "LOFI LOFI_2band-1_33966KB", "LOFI LOFI_2band-2_33966KB"]

window_size = "512" #@param ["272", "320", "352", "480", "512"] {allow-input: true}
aggressiveness = 0.2 #@param {type:"slider", min:0.1, max:1, step:0.1}
aggressiveness = float(aggressiveness)

tta = True #@param {type:"boolean"}
if tta == True:
    tta = "-t"
else:
    tta = ""

high_end_process = "mirroring" #@param ["none","mirroring" , "bypass", "correlation"]
if high_end_process == "none":
  high_end_process = "-H none"
elif high_end_process == "mirroring":
  high_end_process = "-H mirroring"
elif high_end_process == "bypass":
  high_end_process = "-H bypass"
else:
  high_end_process = "-H correlation"

postprocess = False #@param {type:"boolean"}
if postprocess == True:
    postprocess = "-p"
else:
    postprocess = ""

DeepExtraction = False #@param {type:"boolean"}
if DeepExtraction == True:
  DeepExtraction = "-D"
else:
  DeepExtraction = ""

Convert_To = "MP3" #@param ["None", "MP3", "AAC", "FLAC"]
if Convert_To == "None":
  convert_true = 'no'
else:
  convert_true = 'yes'

keep_wav_files = False #@param {type:"boolean"}

## CONVERSION SCRIPT

def move_to_temp():
  os.chdir(f'{drive_path}/UVR_v5')
  print(f'Preparing output directory...')
  print("")
  Path(temp_folder).mkdir(parents=True, exist_ok=True)
  for filename in os.listdir(input_folder):
    if (filename.endswith(my_suffixes)):
      shutil.move(os.path.join(input_folder, filename), os.path.join(temp_folder, filename))
      print(f'{filename} moved to temporary folder')

  convert_true = "moved"
  time.sleep(4)
  clear_output()

def converted_moveback():
  clear_output()
  Path(output_folder).mkdir(parents=True, exist_ok=True)
  for filename in os.listdir(temp_folder):
    if (filename.endswith(my_suffixes)):
      shutil.move(os.path.join(temp_folder, filename), os.path.join(input_folder, filename))
      print(f'{filename} moved back to output folder')

  convert_true = "no"
  time.sleep(5)
  os.rmdir(temp_folder)
  clear_output()

def start_conversion():
  convert_true = "no"
  print("")
  print(f"Conversion to {Convert_To} will start in a few seconds...")
  time.sleep(6)
  clear_output()
  from pathlib import Path
  Path(output_folder).mkdir(parents=True, exist_ok=True)

  if Convert_To == "MP3":
    for filename in os.listdir(input_folder):
      if (filename.endswith(my_suffixes)):
        print('Converting {}'.format(filename))
        # !ffmpeg -loglevel error -nostats -y -i "$input_folder/{filename}" -vn -ar 44100 -ac 2 -b:a 320k "$output_folder/{filename}.mp3"
    print("Finalizing...")
    time.sleep(5) #cooldown
    convpath = './separated/converted'
    for root, dirs, files in os.walk(convpath):
      for file_name in files:
        if '.wav' in file_name:
          file_name_new = file_name.replace('.wav', '')
          os.rename(root + '/' + file_name, root + '/' + file_name_new)

    if keep_wav_files == False:
      # !rm ./separated/*.wav
      time.sleep(3)

    converted_moveback()

  elif Convert_To =="AAC":
    for filename in os.listdir(input_folder):
      if (filename.endswith(my_suffixes)):
        print('Converting {}'.format(filename))
        # !ffmpeg -loglevel error -nostats -y -i "$input_folder/{filename}" -vn -ar 44100 -ac 2 -b:a 320k "$output_folder/{filename}.m4a"
    print("Finalizing...")
    time.sleep(5) #cooldown
    convpath = './separated/converted'
    for root, dirs, files in os.walk(convpath):
      for file_name in files:
        if '.wav' in file_name:
          file_name_new = file_name.replace('.wav', '')
          os.rename(root + '/' + file_name, root + '/' + file_name_new)

    if keep_wav_files == False:
      # !rm ./separated/*.wav
      time.sleep(3)

    converted_moveback()

  elif Convert_To =="FLAC":
    for filename in os.listdir(input_folder):
      if (filename.endswith(my_suffixes)):
        print('Converting {}'.format(filename))
        # !ffmpeg -loglevel error -nostats -y -i "$input_folder/{filename}" -compression_level 4 "$output_folder/{filename}.flac"
    print("Finalizing...")
    time.sleep(5) #cooldown
    convpath = './separated/converted'
    for root, dirs, files in os.walk(convpath):
      for file_name in files:
        if '.wav' in file_name:
          file_name_new = file_name.replace('.wav', '')
          os.rename(root + '/' + file_name, root + '/' + file_name_new)

    if keep_wav_files == False:
      # !rm ./separated/*.wav
      time.sleep(3)

    converted_moveback()

if convert_true == "yes":
  move_to_temp()

def run_inference():
  run_true = "no"

  ## MODEL 1
  if Model == "HP2-4BAND-3090_4band_1":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/HP2-4BAND-3090_4band_1.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_1))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/HP2-4BAND-3090_4band_1.pth" -g 0 -m "modelparams/4band_44100.json" -n 537238KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/HP2-4BAND-3090_4band_1.pth" -g 0 -m "modelparams/4band_44100.json" -n 537238KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 2
  elif Model == "HP2-4BAND-3090_4band_2":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/HP2-4BAND-3090_4band_2.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_2))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/HP2-4BAND-3090_4band_2.pth" -g 0 -m "modelparams/4band_44100.json" -n 537238KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/HP2-4BAND-3090_4band_2.pth" -g 0 -m "modelparams/4band_44100.json" -n 537238KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 3
  elif Model == "HP_4BAND_3090":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/HP_4BAND_3090.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_3))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/HP_4BAND_3090.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/HP_4BAND_3090.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 4
  elif Model == "HighPrecison_4band_1":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/HighPrecison_4band_1.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_4))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/HighPrecison_4band_1.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/HighPrecison_4band_1.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 5
  elif Model == "HighPrecison_4band_2":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/HighPrecison_4band_2.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_5))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/HighPrecison_4band_2.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/HighPrecison_4band_2.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 6
  elif Model == "NewLayer_4band_1":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/NewLayer_4band_1.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_6))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/NewLayer_4band_1.pth" -g 0 -m "modelparams/4band_44100.json" -n 129605KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/NewLayer_4band_1.pth" -g 0 -m "modelparams/4band_44100.json" -n 129605KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 7
  elif Model == "NewLayer_4band_2":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/NewLayer_4band_2.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_7))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/NewLayer_4band_2.pth" -g 0 -m "modelparams/4band_44100.json" -n 129605KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/NewLayer_4band_2.pth" -g 0 -m "modelparams/4band_44100.json" -n 129605KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 8
  elif Model == "NewLayer_4band_3":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/NewLayer_4band_3.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_8))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/NewLayer_4band_3.pth" -g 0 -m "modelparams/4band_44100.json" -n 129605KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/NewLayer_4band_3.pth" -g 0 -m "modelparams/4band_44100.json" -n 129605KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 9
  elif Model == "MGM-v5-2Band-32000-BETA1":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-2Band-32000-BETA1.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_9))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-2Band-32000-BETA1.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-2Band-32000-BETA1.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 10
  elif Model == "MGM-v5-2Band-32000-BETA2":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-2Band-32000-BETA2.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_10))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-2Band-32000-BETA2.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-2Band-32000-BETA2.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 11
  elif Model == "MGM-v5-3Band-44100-BETA":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-3Band-44100-BETA.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_11))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-3Band-44100-BETA.pth" -g 0 -m "modelparams/3band_44100.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-3Band-44100-BETA.pth" -g 0 -m "modelparams/3band_44100.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 12
  elif Model == "MGM-v5-4Band-44100-BETA1":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-4Band-44100-BETA1.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_12))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-4Band-44100-BETA1.pth" -g 0 -m "modelparams/4band_44100.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-4Band-44100-BETA1.pth" -g 0 -m "modelparams/4band_44100.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 13
  elif Model == "MGM-v5-4Band-44100-BETA2":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-4Band-44100-BETA2.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_13))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-4Band-44100-BETA2.pth" -g 0 -m "modelparams/4band_44100.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-4Band-44100-BETA2.pth" -g 0 -m "modelparams/4band_44100.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 14
  elif Model == "MGM-v5-MIDSIDE-44100-BETA1":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-MIDSIDE-44100-BETA1.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_14))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-MIDSIDE-44100-BETA1.pth" -g 0 -m "modelparams/3band_44100_mid.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-MIDSIDE-44100-BETA1.pth" -g 0 -m "modelparams/3band_44100_mid.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 15
  elif Model == "MGM-v5-MIDSIDE-44100-BETA2":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-MIDSIDE-44100-BETA2.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_15))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-MIDSIDE-44100-BETA2.pth" -g 0 -m "modelparams/3band_44100_mid.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-MIDSIDE-44100-BETA2.pth" -g 0 -m "modelparams/3band_44100_mid.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 16
  elif Model == "VOCAL Vocal_HP_4BAND_3090":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/Vocal_HP_4BAND_3090.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_16))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/Vocal_HP_4BAND_3090.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/Vocal_HP_4BAND_3090.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 17
  elif Model == "VOCAL Vocal_HP_4BAND_3090_AGG":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/Vocal_HP_4BAND_3090_AGG.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_17))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/Vocal_HP_4BAND_3090_AGG.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/Vocal_HP_4BAND_3090_AGG.pth" -g 0 -m "modelparams/4band_44100.json" -n 123821KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 18
  elif Model == "VOCAL MGM-v5-Vocal_2Band-32000-BETA1":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-Vocal_2Band-32000-BETA1.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_18))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-Vocal_2Band-32000-BETA1.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-Vocal_2Band-32000-BETA1.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 19
  elif Model == "VOCAL MGM-v5-Vocal_2Band-32000-BETA2":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-Vocal_2Band-32000-BETA2.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_19))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-Vocal_2Band-32000-BETA2.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-Vocal_2Band-32000-BETA2.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 20
  elif Model == "KARAOKE MGM-v5-KAROKEE-32000-BETA1":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-KAROKEE-32000-BETA1.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_20))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-KAROKEE-32000-BETA1.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-KAROKEE-32000-BETA1.pth" -g 0 -m "modelparams/2band_32000.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 21
  elif Model == "KARAOKE MGM-v5-KAROKEE-32000-BETA2-AGR":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/MGM-v5-KAROKEE-32000-BETA2-AGR.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_21))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/MGM-v5-KAROKEE-32000-BETA2-AGR.pth" -g 0 -m "modelparams/2band_32000_agr.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/MGM-v5-KAROKEE-32000-BETA2-AGR.pth" -g 0 -m "modelparams/2band_32000_agr.json" -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 22
  elif Model == "LOFI LOFI_2band-1_33966KB":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/LOFI_2band-1_33966KB.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_22))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/LOFI_2band-1_33966KB.pth" -g 0 -m "modelparams/2band_44100_lofi.json" -n 33966KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/LOFI_2band-1_33966KB.pth" -g 0 -m "modelparams/2band_44100_lofi.json" -n 33966KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

  ## MODEL 23
  elif Model == "LOFI LOFI_2band-2_33966KB":
    if not path.exists("/content/drive/My Drive/UVR_v5/models/LOFI_2band-2_33966KB.pth"):
      print("Downloading model...")
      with hide_opt():
        os.chdir(f'{drive_path}/UVR_v5/models')
        get_ipython().system('wget {}'.format(model_23))
        time.sleep(3)

    os.chdir(f'{drive_path}/UVR_v5')
    print(f'Starting inference process using model {Model}')
    if All_Files == True:

      print("The following tracks will be processed:")
      print("")
      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print(format(filename))

      time.sleep(6)
      clear_output()

      for filename in os.listdir(Folder):
        if (filename.endswith(my_suffixes)):
          print('Processing {}'.format(filename))
          ! sudo python3 inference.py -i "$Folder/{filename}" -P "models/LOFI_2band-2_33966KB.pth" -g 0 -m "modelparams/2band_44100_lofi.json" -n 33966KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

    elif All_Files == False:
      if not path.exists(f"{Folder}/{Input}"):
        print(f"Could not process {drive_path}/{Input}. Not found.")
        sys.exit()
      print("Processing " + (Input))
      ! sudo python3 inference.py -i "$Folder$Input" -P "models/LOFI_2band-2_33966KB.pth" -g 0 -m "modelparams/2band_44100_lofi.json" -n 33966KB -w $window_size $postprocess $tta $high_end_process $DeepExtraction -A $aggressiveness

if run_true == "yes":
  run_inference()

if convert_true =="yes":
  start_conversion()

if convert_true == "moved":
  start_conversion()

if Convert_To =="None":
  clear_output()
  print("Finished on " + datetime.datetime.now().strftime("%d/%m/%Y at %H:%M:%S"))

else:
  print("Finished on " + datetime.datetime.now().strftime("%d/%m/%Y at %H:%M:%S"))
# Out:
# Processing chunk_013.wav
# loading model... done
# /content/drive/My Drive/UVR_v5/inference.py:145: FutureWarning: Pass sr=44100, mono=False as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   X_wave[d], _ = librosa.load(
# /content/drive/My Drive/UVR_v5/lib/spec_utils.py:52: FutureWarning: Pass n_fft=768 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_right = librosa.stft(wave_right, n_fft, hop_length=hop_length)
# /content/drive/My Drive/UVR_v5/inference.py:151: FutureWarning: Pass orig_sr=44100, target_sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   X_wave[d] = librosa.resample(X_wave[d+1], mp.param['band'][d+1]['sr'], bp['sr'], res_type=bp['res_type'])
# ...
